# %% [markdown]
# 2D Slices extraction... refer the depths in kitsWorkspace_8 notebook

# %%
import os
import nibabel as nib
import numpy as np

# Define the paths for the original images and masks
image_folder = "D:/kits23/resampled_and_sliced_images/"
mask_folder = "D:/kits23/resampled_and_sliced_segmentation_files/"
output_image_folder = "D:/kits23/2d_slices/images/"
output_mask_folder = "D:/kits23/2d_slices/masks/"

# Create the output directories if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_mask_folder, exist_ok=True)

# Get the list of image files
image_files = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.endswith('windowed.nii.gz_resampled_and_sliced.nii.gz')]

# Generate the corresponding mask files based on the adjusted naming convention
mask_files = [
    os.path.join(mask_folder, f.replace('windowed.nii.gz_resampled_and_sliced.nii.gz', 'segmentation_resampled_and_sliced.nii.gz'))
    for f in os.listdir(image_folder) if f.endswith('windowed.nii.gz_resampled_and_sliced.nii.gz')
]

# Function to save 2D slices (images and masks) as .nii.gz files in case-specific folders
def save_slices(image_file, mask_file):
    # Check if the mask file exists
    if not os.path.exists(mask_file):
        print(f"Warning: Mask file {mask_file} does not exist.")
        return

    # Load the 3D image and mask
    image = nib.load(image_file).get_fdata()
    mask = nib.load(mask_file).get_fdata()

    # Extract the case number from the filename
    case_number = os.path.basename(image_file).split('_')[1]

    # Create directories for this case if they don't exist
    case_image_folder = os.path.join(output_image_folder, case_number)
    case_mask_folder = os.path.join(output_mask_folder, case_number)
    os.makedirs(case_image_folder, exist_ok=True)
    os.makedirs(case_mask_folder, exist_ok=True)

    # Iterate through each slice along the z-axis
    for i in range(image.shape[0]):
        slice_image = image[i, :, :]
        slice_mask = mask[i, :, :]

        # Create new 3D image objects with one slice (adding a new dimension)
        slice_image_3d = np.expand_dims(slice_image, axis=0)
        slice_mask_3d = np.expand_dims(slice_mask, axis=0)

        # Create the NIfTI image objects
        nifti_image = nib.Nifti1Image(slice_image_3d, affine=np.eye(4))
        nifti_mask = nib.Nifti1Image(slice_mask_3d, affine=np.eye(4))

        # Save the image and mask slices as .nii.gz files in the respective case folders
        slice_image_path = os.path.join(case_image_folder, f"slice_{i:03d}.nii.gz")
        slice_mask_path = os.path.join(case_mask_folder, f"slice_{i:03d}.nii.gz")

        nib.save(nifti_image, slice_image_path)
        nib.save(nifti_mask, slice_mask_path)

# Process each image and mask pair
for image_file, mask_file in zip(image_files, mask_files):
    save_slices(image_file, mask_file)

print("2D image and mask slices extraction and saving completed.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 66
#      64 # Process each image and mask pair
#      65 for image_file, mask_file in zip(image_files, mask_files):
# ---> 66     save_slices(image_file, mask_file)
#      68 print("2D image and mask slices extraction and saving completed.")
#
# Cell In[2], line 61, in save_slices(image_file, mask_file)
#      58 slice_image_path = os.path.join(case_image_folder, f"slice_{i:03d}.nii.gz")
#      59 slice_mask_path = os.path.join(case_mask_folder, f"slice_{i:03d}.nii.gz")
# ---> 61 nib.save(nifti_image, slice_image_path)
#      62 nib.save(nifti_mask, slice_mask_path)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\loadsave.py:164, in save(img, filename, **kwargs)
#     162 # Save the type as expected
#     163 try:
# --> 164     img.to_filename(filename, **kwargs)
#     165 except ImageFileError:
#     166     pass
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\filebasedimages.py:308, in FileBasedImage.to_filename(self, filename, **kwargs)
#     292 r"""Write image to files implied by filename string
#     293
#     294 Parameters
#    (...)
#     305 None
#     306 """
#     307 self.file_map = self.filespec_to_file_map(filename)
# --> 308 self.to_file_map(**kwargs)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\nifti1.py:2377, in Nifti1Pair.to_file_map(self, file_map, dtype)
#    2375 self.get_data_dtype(finalize=True)
#    2376 try:
# -> 2377     super().to_file_map(file_map, dtype)
#    2378 finally:
#    2379     self.set_data_dtype(img_dtype)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\analyze.py:1054, in AnalyzeImage.to_file_map(self, file_map, dtype)
#    1052 seek_tell(imgf, hdr.get_data_offset(), write0=True)
#    1053 # Write array data
# -> 1054 arr_writer.to_fileobj(imgf)
#    1055 hdrf.close_if_mine()
#    1056 if not hdr_img_same:
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\arraywriters.py:526, in SlopeInterArrayWriter.to_fileobj(self, fileobj, order)
#     517 """Write array into `fileobj`
#     518
#     519 Parameters
#    (...)
#     523     order (Fortran or C) to which to write array
#     524 """
#     525 mn, mx = self._writing_range()
# --> 526 array_to_file(
#     527     self._array,
#     528     fileobj,
#     529     self._out_dtype,
#     530     offset=None,
#     531     intercept=self.inter,
#     532     divslope=self.slope,
#     533     mn=mn,
#     534     mx=mx,
#     535     order=order,
#     536     nan2zero=self._needs_nan2zero(),
#     537 )
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\volumeutils.py:607, in array_to_file(data, fileobj, out_dtype, offset, intercept, divslope, mn, mx, order, nan2zero)
#     605     pre_clips = _dt_min_max(in_dtype, *pre_clips)
#     606 if null_scaling and np.can_cast(in_dtype, out_dtype):
# --> 607     return _write_data(data, fileobj, out_dtype, order, pre_clips=pre_clips)
#     608 # Force upcasting for floats by making atleast_1d.
#     609 slope, inter = (np.atleast_1d(v) for v in (divslope, intercept))
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\volumeutils.py:786, in _write_data(data, fileobj, out_dtype, order, in_cast, pre_clips, inter, slope, post_clips, nan_fill)
#     784 if dslice.dtype != out_dtype:
#     785     dslice = dslice.astype(out_dtype)
# --> 786 fileobj.write(dslice.tobytes())
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\openers.py:231, in Opener.write(self, b)
#     230 def write(self, b: bytes, /) -> int | None:
# --> 231     return self.fobj.write(b)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\gzip.py:289, in GzipFile.write(self, data)
#     286     length = data.nbytes
#     288 if length > 0:
# --> 289     self.fileobj.write(self.compress.compress(data))
#     290     self.size += length
#     291     self.crc = zlib.crc32(data, self.crc)
#
# KeyboardInterrupt:

# %%
import os
import nibabel as nib
import numpy as np

# Define the paths for the original images and masks
image_folder = "D:/kits23/resampled_and_sliced_images/"
mask_folder = "D:/kits23/resampled_and_sliced_segmentation_files/"
output_image_folder = "D:/kits23/2d_slices/images/"
output_mask_folder = "D:/kits23/2d_slices/masks/"

# Create the output directories if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_mask_folder, exist_ok=True)

# Get the list of image files
image_files = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.endswith('windowed.nii.gz_resampled_and_sliced.nii.gz')]

# Generate the corresponding mask files based on the adjusted naming convention
mask_files = [
    os.path.join(mask_folder, f.replace('windowed.nii.gz_resampled_and_sliced.nii.gz', 'segmentation_resampled_and_sliced.nii.gz'))
    for f in os.listdir(image_folder) if f.endswith('windowed.nii.gz_resampled_and_sliced.nii.gz')
]

# Function to save 2D slices (images and masks) as .nii.gz files in case-specific folders
def save_slices(image_file, mask_file):
    # Check if the mask file exists
    if not os.path.exists(mask_file):
        print(f"Warning: Mask file {mask_file} does not exist.")
        return

    # Load the 3D image and mask
    image = nib.load(image_file).get_fdata()
    mask = nib.load(mask_file).get_fdata()

    # Extract the case number from the filename
    case_number = os.path.basename(image_file).split('_')[1]

    # Create directories for this case if they don't exist
    case_image_folder = os.path.join(output_image_folder, case_number)
    case_mask_folder = os.path.join(output_mask_folder, case_number)
    os.makedirs(case_image_folder, exist_ok=True)
    os.makedirs(case_mask_folder, exist_ok=True)

    # Iterate through each slice along the z-axis
    for i in range(image.shape[0]):
        slice_image = image[i, :, :]
        slice_mask = mask[i, :, :]

        # Create new 3D image objects with one slice (adding a new dimension)
        slice_image_3d = np.expand_dims(slice_image, axis=0)
        slice_mask_3d = np.expand_dims(slice_mask, axis=0)

        # Create the NIfTI image objects
        nifti_image = nib.Nifti1Image(slice_image_3d, affine=np.eye(4))
        nifti_mask = nib.Nifti1Image(slice_mask_3d, affine=np.eye(4))

        # Save the image and mask slices as .nii.gz files in the respective case folders
        slice_image_path = os.path.join(case_image_folder, f"slice_{i:03d}.nii.gz")
        slice_mask_path = os.path.join(case_mask_folder, f"slice_{i:03d}.nii.gz")

        nib.save(nifti_image, slice_image_path)
        nib.save(nifti_mask, slice_mask_path)

    # Print progress after processing all slices of a case
    print(f"Case {case_number} processing completed.")

# Process each image and mask pair
for image_file, mask_file in zip(image_files, mask_files):
    save_slices(image_file, mask_file)

print("2D image and mask slices extraction and saving completed.")
# Out:
# Case 00000 processing completed.
# Case 00001 processing completed.
# Case 00002 processing completed.
# Case 00003 processing completed.
# Case 00004 processing completed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 69
#      67 # Process each image and mask pair
#      68 for image_file, mask_file in zip(image_files, mask_files):
# ---> 69     save_slices(image_file, mask_file)
#      71 print("2D image and mask slices extraction and saving completed.")
#
# Cell In[3], line 61, in save_slices(image_file, mask_file)
#      58     slice_image_path = os.path.join(case_image_folder, f"slice_{i:03d}.nii.gz")
#      59     slice_mask_path = os.path.join(case_mask_folder, f"slice_{i:03d}.nii.gz")
# ---> 61     nib.save(nifti_image, slice_image_path)
#      62     nib.save(nifti_mask, slice_mask_path)
#      64 # Print progress after processing all slices of a case
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\loadsave.py:164, in save(img, filename, **kwargs)
#     162 # Save the type as expected
#     163 try:
# --> 164     img.to_filename(filename, **kwargs)
#     165 except ImageFileError:
#     166     pass
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\filebasedimages.py:308, in FileBasedImage.to_filename(self, filename, **kwargs)
#     292 r"""Write image to files implied by filename string
#     293
#     294 Parameters
#    (...)
#     305 None
#     306 """
#     307 self.file_map = self.filespec_to_file_map(filename)
# --> 308 self.to_file_map(**kwargs)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\nifti1.py:2377, in Nifti1Pair.to_file_map(self, file_map, dtype)
#    2375 self.get_data_dtype(finalize=True)
#    2376 try:
# -> 2377     super().to_file_map(file_map, dtype)
#    2378 finally:
#    2379     self.set_data_dtype(img_dtype)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\analyze.py:1054, in AnalyzeImage.to_file_map(self, file_map, dtype)
#    1052 seek_tell(imgf, hdr.get_data_offset(), write0=True)
#    1053 # Write array data
# -> 1054 arr_writer.to_fileobj(imgf)
#    1055 hdrf.close_if_mine()
#    1056 if not hdr_img_same:
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\arraywriters.py:526, in SlopeInterArrayWriter.to_fileobj(self, fileobj, order)
#     517 """Write array into `fileobj`
#     518
#     519 Parameters
#    (...)
#     523     order (Fortran or C) to which to write array
#     524 """
#     525 mn, mx = self._writing_range()
# --> 526 array_to_file(
#     527     self._array,
#     528     fileobj,
#     529     self._out_dtype,
#     530     offset=None,
#     531     intercept=self.inter,
#     532     divslope=self.slope,
#     533     mn=mn,
#     534     mx=mx,
#     535     order=order,
#     536     nan2zero=self._needs_nan2zero(),
#     537 )
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\volumeutils.py:607, in array_to_file(data, fileobj, out_dtype, offset, intercept, divslope, mn, mx, order, nan2zero)
#     605     pre_clips = _dt_min_max(in_dtype, *pre_clips)
#     606 if null_scaling and np.can_cast(in_dtype, out_dtype):
# --> 607     return _write_data(data, fileobj, out_dtype, order, pre_clips=pre_clips)
#     608 # Force upcasting for floats by making atleast_1d.
#     609 slope, inter = (np.atleast_1d(v) for v in (divslope, intercept))
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\volumeutils.py:786, in _write_data(data, fileobj, out_dtype, order, in_cast, pre_clips, inter, slope, post_clips, nan_fill)
#     784 if dslice.dtype != out_dtype:
#     785     dslice = dslice.astype(out_dtype)
# --> 786 fileobj.write(dslice.tobytes())
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\openers.py:231, in Opener.write(self, b)
#     230 def write(self, b: bytes, /) -> int | None:
# --> 231     return self.fobj.write(b)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\gzip.py:289, in GzipFile.write(self, data)
#     286     length = data.nbytes
#     288 if length > 0:
# --> 289     self.fileobj.write(self.compress.compress(data))
#     290     self.size += length
#     291     self.crc = zlib.crc32(data, self.crc)
#
# KeyboardInterrupt:

# %%
import os
import nibabel as nib
import numpy as np
import json

# Define the paths for the original images and masks
image_folder = "D:/kits23/resampled_and_sliced_images/"
mask_folder = "D:/kits23/resampled_and_sliced_segmentation_files/"
output_image_folder = "D:/kits23/2d_slices/images/"
output_mask_folder = "D:/kits23/2d_slices/masks/"
progress_file = "D:/kits23/processed_cases.json"  # JSON file to store progress

# Load the progress file (if exists)
if os.path.exists(progress_file):
    with open(progress_file, 'r') as f:
        processed_cases = json.load(f)
else:
    processed_cases = {}

# Create the output directories if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_mask_folder, exist_ok=True)

# Get the list of image files
image_files = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.endswith('windowed.nii.gz_resampled_and_sliced.nii.gz')]

# Generate the corresponding mask files based on the adjusted naming convention
mask_files = [
    os.path.join(mask_folder, f.replace('windowed.nii.gz_resampled_and_sliced.nii.gz', 'segmentation_resampled_and_sliced.nii.gz'))
    for f in os.listdir(image_folder) if f.endswith('windowed.nii.gz_resampled_and_sliced.nii.gz')
]

# Function to save 2D slices (images and masks) as .nii.gz files in case-specific folders
def save_slices(image_file, mask_file):
    # Extract the case number from the filename
    case_number = os.path.basename(image_file).split('_')[1]

    # Skip if this case has already been processed
    if case_number in processed_cases:
        print(f"Skipping case {case_number}, already processed.")
        return

    # Check if the mask file exists
    if not os.path.exists(mask_file):
        print(f"Warning: Mask file {mask_file} does not exist.")
        return

    # Load the 3D image and mask
    image = nib.load(image_file).get_fdata()
    mask = nib.load(mask_file).get_fdata()

    # Create directories for this case if they don't exist
    case_image_folder = os.path.join(output_image_folder, case_number)
    case_mask_folder = os.path.join(output_mask_folder, case_number)
    os.makedirs(case_image_folder, exist_ok=True)
    os.makedirs(case_mask_folder, exist_ok=True)

    # Iterate through each slice along the z-axis
    for i in range(image.shape[0]):
        slice_image = image[i, :, :]
        slice_mask = mask[i, :, :]

        # Create new 3D image objects with one slice (adding a new dimension)
        slice_image_3d = np.expand_dims(slice_image, axis=0)
        slice_mask_3d = np.expand_dims(slice_mask, axis=0)

        # Create the NIfTI image objects
        nifti_image = nib.Nifti1Image(slice_image_3d, affine=np.eye(4))
        nifti_mask = nib.Nifti1Image(slice_mask_3d, affine=np.eye(4))

        # Save the image and mask slices as .nii.gz files in the respective case folders
        slice_image_path = os.path.join(case_image_folder, f"slice_{i:03d}.nii.gz")
        slice_mask_path = os.path.join(case_mask_folder, f"slice_{i:03d}.nii.gz")

        nib.save(nifti_image, slice_image_path)
        nib.save(nifti_mask, slice_mask_path)

    # Print progress after processing all slices of a case
    print(f"Case {case_number} processing completed.")

    # Mark the case as processed
    processed_cases[case_number] = True

    # Save the progress to the file
    with open(progress_file, 'w') as f:
        json.dump(processed_cases, f)

# Process each image and mask pair
for image_file, mask_file in zip(image_files, mask_files):
    save_slices(image_file, mask_file)

print("2D image and mask slices extraction and saving completed.")
# Out:
# Case 00000 processing completed.
# Case 00001 processing completed.
# Case 00002 processing completed.
# Case 00003 processing completed.
# Case 00004 processing completed.
# Case 00005 processing completed.
# Case 00006 processing completed.
# Case 00007 processing completed.
# Case 00008 processing completed.
# Case 00009 processing completed.
# Case 00010 processing completed.
# Case 00011 processing completed.
# Case 00012 processing completed.
# Case 00013 processing completed.
# Case 00014 processing completed.
# Case 00015 processing completed.
# Case 00016 processing completed.
# Case 00017 processing completed.
# Case 00018 processing completed.
# Case 00019 processing completed.
# Case 00020 processing completed.
# Case 00021 processing completed.
# Case 00022 processing completed.
# Case 00023 processing completed.
# Case 00024 processing completed.
# Case 00025 processing completed.
# Case 00026 processing completed.
# Case 00027 processing completed.
# Case 00028 processing completed.
# Case 00029 processing completed.
# Case 00030 processing completed.
# Case 00031 processing completed.
# Case 00032 processing completed.
# Case 00033 processing completed.
# Case 00034 processing completed.
# Case 00035 processing completed.
# Case 00036 processing completed.
# Case 00037 processing completed.
# Case 00038 processing completed.
# Case 00039 processing completed.
# Case 00040 processing completed.
# Case 00041 processing completed.
# Case 00042 processing completed.
# Case 00043 processing completed.
# Case 00044 processing completed.
# Case 00045 processing completed.
# Case 00046 processing completed.
# Case 00047 processing completed.
# Case 00048 processing completed.
# Case 00049 processing completed.
# Case 00050 processing completed.
# Case 00051 processing completed.
# Case 00052 processing completed.
# Case 00053 processing completed.
# Case 00054 processing completed.
# Case 00055 processing completed.
# Case 00056 processing completed.
# Case 00057 processing completed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 90
#      88 # Process each image and mask pair
#      89 for image_file, mask_file in zip(image_files, mask_files):
# ---> 90     save_slices(image_file, mask_file)
#      92 print("2D image and mask slices extraction and saving completed.")
#
# Cell In[1], line 75, in save_slices(image_file, mask_file)
#      72     slice_image_path = os.path.join(case_image_folder, f"slice_{i:03d}.nii.gz")
#      73     slice_mask_path = os.path.join(case_mask_folder, f"slice_{i:03d}.nii.gz")
# ---> 75     nib.save(nifti_image, slice_image_path)
#      76     nib.save(nifti_mask, slice_mask_path)
#      78 # Print progress after processing all slices of a case
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\loadsave.py:164, in save(img, filename, **kwargs)
#     162 # Save the type as expected
#     163 try:
# --> 164     img.to_filename(filename, **kwargs)
#     165 except ImageFileError:
#     166     pass
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\filebasedimages.py:308, in FileBasedImage.to_filename(self, filename, **kwargs)
#     292 r"""Write image to files implied by filename string
#     293
#     294 Parameters
#    (...)
#     305 None
#     306 """
#     307 self.file_map = self.filespec_to_file_map(filename)
# --> 308 self.to_file_map(**kwargs)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\nifti1.py:2377, in Nifti1Pair.to_file_map(self, file_map, dtype)
#    2375 self.get_data_dtype(finalize=True)
#    2376 try:
# -> 2377     super().to_file_map(file_map, dtype)
#    2378 finally:
#    2379     self.set_data_dtype(img_dtype)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\analyze.py:1054, in AnalyzeImage.to_file_map(self, file_map, dtype)
#    1052 seek_tell(imgf, hdr.get_data_offset(), write0=True)
#    1053 # Write array data
# -> 1054 arr_writer.to_fileobj(imgf)
#    1055 hdrf.close_if_mine()
#    1056 if not hdr_img_same:
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\arraywriters.py:526, in SlopeInterArrayWriter.to_fileobj(self, fileobj, order)
#     517 """Write array into `fileobj`
#     518
#     519 Parameters
#    (...)
#     523     order (Fortran or C) to which to write array
#     524 """
#     525 mn, mx = self._writing_range()
# --> 526 array_to_file(
#     527     self._array,
#     528     fileobj,
#     529     self._out_dtype,
#     530     offset=None,
#     531     intercept=self.inter,
#     532     divslope=self.slope,
#     533     mn=mn,
#     534     mx=mx,
#     535     order=order,
#     536     nan2zero=self._needs_nan2zero(),
#     537 )
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\volumeutils.py:607, in array_to_file(data, fileobj, out_dtype, offset, intercept, divslope, mn, mx, order, nan2zero)
#     605     pre_clips = _dt_min_max(in_dtype, *pre_clips)
#     606 if null_scaling and np.can_cast(in_dtype, out_dtype):
# --> 607     return _write_data(data, fileobj, out_dtype, order, pre_clips=pre_clips)
#     608 # Force upcasting for floats by making atleast_1d.
#     609 slope, inter = (np.atleast_1d(v) for v in (divslope, intercept))
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\volumeutils.py:786, in _write_data(data, fileobj, out_dtype, order, in_cast, pre_clips, inter, slope, post_clips, nan_fill)
#     784 if dslice.dtype != out_dtype:
#     785     dslice = dslice.astype(out_dtype)
# --> 786 fileobj.write(dslice.tobytes())
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\site-packages\nibabel\openers.py:231, in Opener.write(self, b)
#     230 def write(self, b: bytes, /) -> int | None:
# --> 231     return self.fobj.write(b)
#
# File c:\Users\PRAGNA\AppData\Local\Programs\Python\Python310\lib\gzip.py:289, in GzipFile.write(self, data)
#     286     length = data.nbytes
#     288 if length > 0:
# --> 289     self.fileobj.write(self.compress.compress(data))
#     290     self.size += length
#     291     self.crc = zlib.crc32(data, self.crc)
#
# KeyboardInterrupt:
